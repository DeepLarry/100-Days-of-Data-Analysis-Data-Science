# %%
#Weekly Temprature
#Compare temprature of cities over a week using subplots & loops.

# %%
#Task
import matplotlib.pyplot as plt
import numpy as np

days = ["Mon","Tue","Wed","Thu","Fri"]

cities = ["New york","London","Delhi","Tokyo"]

tempretures = [
    [22,23,21,24,25],  #New York
    [18,19,17,20,21],  #London
    [30,32,31,33,34],  #Delhi
    [25,26,24,27,28]   #Tokyo
]

fig,axes = plt.subplots(2,2)

#0,0 -0,1 -1,0 -1,1
# city_no= 0
# for i in range(2):        #row (i)  -0,1
#     for j in range(2):    #cols(j) -0,1
#         axes[i][j].plot(days,tempretures[city_no],marker='o')
#         axes[i][j].plot(days,tempretures[city_no])
#         axes[i][j].grid(True)
#         city_no=city_no+1


#------------------------------------------------------#

# ---Flattern - Convert 2-D array to 1-D array--

# Create a 2D array
# a = np.array([[1, 2], [3, 4]])

# Flatten in row-major (C-style) order
# print(a.flatten()) # Output: [1 2 3 4]

#------------------------------------------------------#
axes=axes.flatten()
for i,ax in enumerate(axes):   #idx, val,at,idx
    ax.plot(days,tempretures[i],marker='o')
    ax.set_title(cities[i])
    
            ax.grid(True)   #👉 Adds background lines → makes graph readable
    
fig.suptitle("Temprature in cities over the week")
fig.supylabel("Temperature")
fig.supxlabel("Days")
fig.tight_layout()
